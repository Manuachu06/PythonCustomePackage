# %%
from json2csv_pro import JSONConverter

# %%
from json2csv_pro import JSONConverter

# %%
from json2csv_pro import JSON2CSVError

converter = JSONConverter()
data = [{"name": "John", "age": 30, "address": {"city": "NYC"}},
        {"name": "Jane", "age": 25, "address": {"city": "LA"}}]

output = converter.convert_to_csv(
    data=data,
    output_file="output.csv",
    flatten_nested=True,
    delimiter=',')

# %%
output

# %%
converter.load_json_file()

# %%
from json2csv_pro import JSONConverter

converter = JSONConverter()

# %%
from json2csv_pro import JSONConverter

# %%
JSONConverter.convert_batch

# %%
from json2csv_pro import JSONConverter

# %%
from json2csv_manu06 import JSONConverter

converter = JSONConverter()
data = [{"name": "Manu", "age": 30, "address": {"city": "NYC"}},
        {"name": "Ajay", "age": 25, "address": {"city": "LA"}}]

output = converter.convert_to_csv(
    data=data,
    output_file="output.csv",
    flatten_nested=True,
    delimiter=',')
